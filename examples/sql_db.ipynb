# %%
import sqlite3

# Create an in-memory SQLite database
conn = sqlite3.connect(':memory:')

# Create a table and insert sample data
conn.execute('''CREATE TABLE users (id INTEGER PRIMARY KEY, name TEXT, age INTEGER)''')
conn.execute("INSERT INTO users (name, age) VALUES ('Alice', 25), ('Bob', 30), ('Charlie', 35)")

# Query the data
cursor = conn.cursor()
cursor.execute("SELECT * FROM users")
rows = cursor.fetchall()
for row in rows:
    print(row)

conn.close()
# Out:
# (1, 'Alice', 25)
# (2, 'Bob', 30)
# (3, 'Charlie', 35)

# %%
conn = sqlite3.connect(':memory:')

with open('/data1/students/srijit/cc/examples/eDosthi_merged.sql', 'r') as f:
    sql_script = f.read()

conn.executescript(sql_script)

# Query the data to verify
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables:", tables)

# Example query, adjust as needed
cursor.execute("SELECT * FROM your_table_name LIMIT 5;")  # Replace 'your_table_name' with actual table name
rows = cursor.fetchall()
for row in rows:
    print(row)

conn.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[4], line 4
#       1 conn = sqlite3.connect(':memory:')
#       3 with open('/data1/students/srijit/cc/examples/eDosthi_merged.sql', 'r') as f:
# ----> 4     sql_script = f.read()
#       6 conn.executescript(sql_script)
#       8 # Query the data to verify
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 1532622: invalid start byte

# %%
conn = sqlite3.connect(':memory:')

with open('/data1/students/srijit/cc/examples/eDosthi_merged.sql', 'r') as f:
	sql_script = f.read()

conn.executescript(sql_script)

cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables:", tables)

conn.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 4
#       1 conn = sqlite3.connect(':memory:')
#       3 with open('/data1/students/srijit/cc/examples/eDosthi_merged.sql', 'r') as f:
# ----> 4 	sql_script = f.read()
#       6 conn.executescript(sql_script)
#       8 cursor = conn.cursor()
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 1532622: invalid start byte
